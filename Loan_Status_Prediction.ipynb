# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Processing

# %%
# loading the dataset to pandas DataFrame
loan_dataset = pd.read_csv("loan_data.csv")
loan_dataset.head(10) # printing first 10 rows of the loan data set
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001015    Male     Yes          0      Graduate            No
# 1  LP001022    Male     Yes          1      Graduate            No
# 2  LP001031    Male     Yes          2      Graduate            No
# 3  LP001035    Male     Yes          2      Graduate            No
# 4  LP001051    Male      No          0  Not Graduate            No
# 5  LP001054    Male     Yes          0  Not Graduate           Yes
# 6  LP001055  Female      No          1  Not Graduate            No
# 7  LP001056    Male     Yes          2  Not Graduate            No
# 8  LP001059    Male     Yes          2      Graduate           NaN
# 9  LP001067    Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
# 5             2165               3422       152.0             360.0
# 6             2226                  0        59.0             360.0
# 7             3881                  0       147.0             360.0
# 8            13633                  0       280.0             240.0
# 9             2400               2400       123.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# 3             NaN         Urban
# 4             1.0         Urban
# 5             1.0         Urban
# 6             1.0     Semiurban
# 7             0.0         Rural
# 8             1.0         Urban
# 9             1.0     Semiurban

# %%
# number of total rows and columns
loan_dataset.shape
# Out:
# (367, 12)

# %%
loan_dataset.isnull().sum() # checking null values in loan dataset
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
loan_dataset.drop_duplicates(inplace = True)
loan_dataset.shape
# Out:
# (367, 12)

# %%
# Removes rows where 'Gender' column has missing values
loan_dataset = loan_dataset.dropna(subset=["Gender"])

loan_dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
loan_dataset["Credit_History"]= loan_dataset["Credit_History"].fillna(0)
loan_dataset["Self_Employed"] = loan_dataset["Self_Employed"].fillna("No")
loan_dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
loan_dataset.dropna(inplace=True)
loan_dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
loan_dataset.shape
# Out:
# (337, 12)

# %%
loan_dataset
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 0               1.0         Urban
# 1               1.0         Urban
# 2               1.0         Urban
# 3               0.0         Urban
# 4               1.0         Urban
# ..              ...           ...
# 362             1.0         Urban
# 363             1.0         Urban
# 364             0.0     Semiurban
# 365             1.0         Rural
# 366             1.0         Rural
#
# [337 rows x 12 columns]

# %%
loan_dataset["Dependents"].value_counts()
# Out:
# dtype('O')

# %%
# data label encoding replacing the value of 3+ to 4
loan_dataset.replace(to_replace="3+", value=4, inplace= True)

# %%
loan_dataset["Dependents"].value_counts()
# Out:
# Dependents
# 0    188
# 2     59
# 1     52
# 4     38
# Name: count, dtype: int64

# %% [markdown]
# # Data Visulization

# %%
loan_dataset.dtypes
# Out:
# Loan_ID              object
# Gender               object
# Married              object
# Dependents           object
# Education            object
# Self_Employed        object
# ApplicantIncome       int64
# CoapplicantIncome     int64
# LoanAmount            Int64
# Loan_Amount_Term      Int64
# Credit_History        Int64
# Property_Area        object
# dtype: object

# %%
loan_dataset["LoanAmount"] = loan_dataset["LoanAmount"].astype('int')
loan_dataset["Loan_Amount_Term"] = loan_dataset["Loan_Amount_Term"].astype('int')
loan_dataset["Dependents"] = loan_dataset["Dependents"].astype('int')

loan_dataset["Credit_History"] = loan_dataset["Credit_History"].astype('int')

# %%
loan_dataset.dtypes
# Out:
# Loan_ID              object
# Gender               object
# Married              object
# Dependents            int64
# Education            object
# Self_Employed        object
# ApplicantIncome       int64
# CoapplicantIncome     int64
# LoanAmount            int64
# Loan_Amount_Term      int64
# Credit_History        int64
# Property_Area        object
# dtype: object

# %%
numeric_columns = ["Dependents",	"ApplicantIncome",	"CoapplicantIncome",	"LoanAmount"]
for col in numeric_columns:
    plt.figure(figsize=(5,3))
    sns.histplot(loan_dataset[col])

# %%
# Education by 
categrical_columns = ["Gender",	"Married",	"Education",	"Self_Employed", "Property_Area", "Credit_History"]
for col in categrical_columns:
    plt.figure(figsize=(4,2))
    sns.countplot(x=loan_dataset[col])

# %%
for col in numeric_columns:
    plt.figure(figsize=(4,2))
    sns.boxplot(x=loan_dataset[col])

# %%
plt.figure(figsize=(6,4))
sns.heatmap(loan_dataset.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
loan_dataset["TotalIncome"] = loan_dataset["ApplicantIncome"] + loan_dataset["CoapplicantIncome"]
loan_dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0         110               360
# 1             3076               1500         126               360
# 2             5000               1800         208               360
# 3             2340               2546         100               360
# 4             3276                  0          78               360
#
#    Credit_History Property_Area  TotalIncome
# 0               1         Urban         5720
# 1               1         Urban         4576
# 2               1         Urban         6800
# 3               0         Urban         4886
# 4               1         Urban         3276

# %%
loan_dataset["LoanToIncomeRatio"] = loan_dataset["LoanAmount"] / (loan_dataset["TotalIncome"] + 1)
loan_dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0         110               360
# 1             3076               1500         126               360
# 2             5000               1800         208               360
# 3             2340               2546         100               360
# 4             3276                  0          78               360
#
#    Credit_History Property_Area  TotalIncome  LoanToIncomeRatio
# 0               1         Urban         5720           0.019227
# 1               1         Urban         4576           0.027529
# 2               1         Urban         6800           0.030584
# 3               0         Urban         4886           0.020462
# 4               1         Urban         3276           0.023802

# %%
loan_dataset["Loan_Status"] = (
        (loan_dataset["Credit_History"] == 1) &
        (loan_dataset["LoanToIncomeRatio"] < 0.35)
    ).astype(int)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(loan_dataset.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
# convert categorical columns to numerical values
loan_dataset.replace({"Married":{"No":0, "Yes":1},
                      "Gender":{"Male":1, "Female":0}, 
                      "Self_Employed": {"No":0, "Yes":1},
                     "Property_Area": {"Rural":0, "Semiurban": 1, "Urban":2},
                     "Education": {"Graduate": 1, "Not Graduate": 0}}, inplace = True)
loan_dataset.head(10)
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0  LP001015       1        1          0          1              0
# 1  LP001022       1        1          1          1              0
# 2  LP001031       1        1          2          1              0
# 3  LP001035       1        1          2          1              0
# 4  LP001051       1        0          0          0              0
# 5  LP001054       1        1          0          0              1
# 6  LP001055       0        0          1          0              0
# 7  LP001056       1        1          2          0              0
# 8  LP001059       1        1          2          1              0
# 9  LP001067       1        0          0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0         110               360
# 1             3076               1500         126               360
# 2             5000               1800         208               360
# 3             2340               2546         100               360
# 4             3276                  0          78               360
# 5             2165               3422         152               360
# 6             2226                  0          59               360
# 7             3881                  0         147               360
# 8            13633                  0         280               240
# 9             2400               2400         123               360
#
#    Credit_History  Property_Area  TotalIncome  LoanToIncomeRatio  Loan_Status
# 0               1              2         5720           0.019227            1
# 1               1              2         4576           0.027529            1
# 2               1              2         6800           0.030584            1
# 3               0              2         4886           0.020462            0
# 4               1              2         3276           0.023802            1
# 5               1              2         5587           0.027201            1
# 6               1              1         2226           0.026493            1
# 7               0              0         3881           0.037867            0
# 8               1              2        13633           0.020537            1
# 9               1              1         4800            0.02562            1

# %%
loan_dataset.rename(columns={
    "Gender": "Is_Male",
    "Married": "Is_Married",
    "Education": "Is_Graduate"
}, inplace=True)
loan_dataset.head()
# Out:
#     Loan_ID  Is_Male  Is_Married Dependents  Is_Graduate  Self_Employed  \
# 0  LP001015        1           1          0            1              0
# 1  LP001022        1           1          1            1              0
# 2  LP001031        1           1          2            1              0
# 3  LP001035        1           1          2            1              0
# 4  LP001051        1           0          0            0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0         110               360
# 1             3076               1500         126               360
# 2             5000               1800         208               360
# 3             2340               2546         100               360
# 4             3276                  0          78               360
#
#    Credit_History  Property_Area  TotalIncome  LoanToIncomeRatio  Loan_Status
# 0               1              2         5720           0.019227            1
# 1               1              2         4576           0.027529            1
# 2               1              2         6800           0.030584            1
# 3               0              2         4886           0.020462            0
# 4               1              2         3276           0.023802            1

# %%
# separating the data and label
X = loan_dataset.drop(columns=["Loan_ID", "Loan_Status"], axis=1)
Y = loan_dataset["Loan_Status"]
print(X)
print(Y)
# Out:
#      Is_Male  Is_Married Dependents  Is_Graduate  Self_Employed  \
# 0          1           1          0            1              0
# 1          1           1          1            1              0
# 2          1           1          2            1              0
# 3          1           1          2            1              0
# 4          1           0          0            0              0
# ..       ...         ...        ...          ...            ...
# 362        1           1          4            0              1
# 363        1           1          0            1              0
# 364        1           0          0            1              0
# 365        1           1          0            1              0
# 366        1           0          0            1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0         110               360
# 1               3076               1500         126               360
# 2               5000               1800         208               360
# 3               2340               2546         100               360
# 4               3276                  0          78               360
# ..               ...                ...         ...               ...
# 362             4009               1777         113               360
# 363             4158                709         115               360
# 364             3250               1993         126               360
# 365             5000               2393         158               360
# 366             9200                  0          98               180
#
#      Credit_History  Property_Area  TotalIncome  LoanToIncomeRatio
# 0                 1              2         5720           0.019227
# 1                 1              2         4576           0.027529
# 2                 1              2         6800           0.030584
# 3                 0              2         4886           0.020462
# 4                 1              2         3276           0.023802
# ..              ...            ...          ...                ...
# 362               1              2         5786           0.019527
# 363               1              2         4867           0.023624
# 364               0              1         5243           0.024027
# 365               1              0         7393           0.021369
# 366               1              0         9200           0.010651
#
# [337 rows x 13 columns]
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 362    1
# 363    1
# 364    0
# 365    1
# 366    1
# Name: Loan_Status, Length: 337, dtype: int64

# %%
# Train test Split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (337, 13) (269, 13) (68, 13)

# %%
# Train the Model using Support Vector Machine Model

# %%
classifier = svm.SVC(kernel="linear")

# %%
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
# Model Evalution
# accuracy score on training data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print("Accuracy on training data:", training_data_accuracy)
# Out:
# Accuracy on training data: 0.9591078066914498

# %%
# Model Evalution
# accuracy score on training data
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print("Accuracy on testing data:", test_data_accuracy)
# Out:
# Accuracy on testing data: 0.9705882352941176
